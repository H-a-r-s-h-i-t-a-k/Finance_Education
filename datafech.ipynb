# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://makeheadway.com/library/topics/financial-literacy/',headers=headers).text

# %%
soup=BeautifulSoup(webpage)
soup.prettify()
print('hhhyess')
# Out:
# hhhhhhhhhkkkkkkkyess

# %%
book=soup.find_all('div',class_='LibraryTopicsList_topic__right-column__nvGbv')
len(book)
# Out:
# 47

# %%
name=[]
auther=[]
rating=[]
discription=[]
c=0
for i in book:
    
    name.append(i.find('h2').text)
    auther.append(i.find('p').text)
    rating.append(i.find_all('span')[4].text[:3])
    discription.append(i.find_all('p')[3].text)
    c+=1
    if c==43:
        break

# name
# auther
# rating
# discription

# %%
df={'name':name,'rating':rating,'auther':auther,'discription':discription}
datafbook=pd.DataFrame(df)

# %%
datafbook.shape
# Out:
# (43, 4)

# %%
datafbook
# Out:
#                                                 name rating  \
# 0                                Get Good with Money    4.9
# 1                           The Vision Driven Leader    4.8
# 2                               Think and Grow Rich!    4.7
# 3                                  Rich Dad Poor Dad    4.7
# 4                            The Psychology of Money    4.7
# 5                           The Total Money Makeover    4.7
# 6                        I Will Teach You to be Rich    4.7
# 7                           The Millionaire Fastlane    4.7
# 8          The Little Book of Common Sense Investing    4.7
# 9                    Secrets of the Millionaire Mind    4.7
# 10                      Rich Dad's Cashflow Quadrant    4.7
# 11                    A Random Walk Down Wall Street    4.7
# 12                                    Capital Gaines    4.7
# 13  The Automatic Millionaire,  Expanded and Updated    4.7
# 14                                  The Latte Factor    4.7
# ...

# %%
datafbook.Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 datafbook.Name
#
# NameError: name 'datafbook' is not defined

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://makeheadway.com/library/topics/financial-literacy/',headers=headers).text

soup=BeautifulSoup(webpage)
soup.prettify()
book=soup.find_all('div',class_='LibraryTopicsList_topic__right-column__nvGbv')
len(book)
name=[]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# Assuming 'datafbook' is the DataFrame you provided
# You can preprocess the data, convert text to TF-IDF vectors
vectorizer = TfidfVectorizer(stop_words='english')
book_vectors = vectorizer.fit_transform(datafbook['discription'])

# Create a KNN model
knn_model = NearestNeighbors(n_neighbors=3, metric='cosine')
knn_model.fit(book_vectors)

def recommend_books(query, k=3):
    # Transform the query using the same vectorizer
    query_vector = vectorizer.transform([query])

    # Find the k nearest neighbors
    _, indices = knn_model.kneighbors(query_vector, n_neighbors=k)

    # Display the recommended books
    recommended_books = datafbook.iloc[indices[0]]
    return recommended_books[['name', 'auther', 'rating', 'discription']]

# Example usage:
query = "I want to learn about managing personal finance"
recommendations = recommend_books(query)
print(recommendations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 # Assuming 'datafbook' is the DataFrame you provided
#       6 # You can preprocess the data, convert text to TF-IDF vectors
#       7 vectorizer = TfidfVectorizer(stop_words='english')
# ----> 8 book_vectors = vectorizer.fit_transform(datafbook['discription'])
#      10 # Create a KNN model
#      11 knn_model = NearestNeighbors(n_neighbors=3, metric='cosine')
#
# NameError: name 'datafbook' is not defined

# %%
class FinanceEducationModel:
    def __init__(self):
        self.topics = {
            'budgeting': ['Budgeting 101', 'The Total Money Makeover', 'Zero-Based Budgeting Guide'],
            'investing': ['The Little Book of Common Sense Investing', 'Stock Market Basics', 'Investing for Beginners'],
            'debt_management': ['Get Good with Money', 'Debt-Free Living Guide', 'Smart Debt Payoff Strategies'],
            # Add more topics and resources as needed
        }

    def get_user_preferences(self):
        print("Welcome to the Personalized Finance Education Model!")
        name = input("What's your name? ")
        print(f"Nice to meet you, {name}!")

        print("\nLet's understand your finance education preferences.")
        topics = list(self.topics.keys())
        print("Available Topics:", topics)
        selected_topics = input("Enter the topics you are interested in (comma-separated): ").split(',')

        return name, selected_topics

    def recommend_resources(self, name, selected_topics):
        print(f"\nThank you, {name}! Here are personalized finance education recommendations for you:")
        for topic in selected_topics:
            if topic in self.topics:
                resources = self.topics[topic]
                print(f"\nResources for {topic}:")
                for index, resource in enumerate(resources, start=1):
                    print(f"{index}. {resource}")
            else:
                print(f"No resources available for the topic: {topic}")

    def run_model(self):
        name, selected_topics = self.get_user_preferences()
        self.recommend_resources(name, selected_topics)

# Instantiate the FinanceEducationModel and run the model
finance_model = FinanceEducationModel()
finance_model.run_model()
# Out:
# Welcome to the Personalized Finance Education Model!
# Nice to meet you, !
#
# Let's understand your finance education preferences.
# Available Topics: ['budgeting', 'investing', 'debt_management']
#
# Thank you, ! Here are personalized finance education recommendations for you:
# No resources available for the topic:
